# %% [markdown]
# ## Main Hartree Code
# <br>
# Hartree-Fock Computational Chemistry Method implemented in Python as described in <u>Modern Quantum Chemistry Introduction to Advanced Electronic Structure Theory</u>, by Attila Szabo and Neil S. Ostlund. <br> <br>
# Throughout the rest of the modules in this notebook, the entire text of Modern Quantum Chemistry will simply be refered to as "Szabo" for the sake of brevity.
# <br> <br>
# Program is limited to molecules consisting of hydrogen and helium with only even numbers of electrons. Required user input is the atomic number, 3D space location, and electron number for each atom. A basis set specification is also required. <br>
# <br>
# The program makes use of Hartree Atomic Units such that the distances and lengths are described in Bohr Radius, energy is in Hartrees and mass is in Hartree Atomic Units, such that the mass of a proton is equal to 1836 atomic units. More information on Hartree Atomic Units can be found on page 41 of Szabo.

# %%
#Python Implementation of the Hartree Fock Method
#Procedures listed in the code follow as described in Modern Quantum Chemistry: 
#Introduction to Advanced Electronic Structure Theory, By Attila Szabo and Neil S. Ostlund
import math
import sys
import numpy as np
from molecule import atom
from molecule import vector
from molecule import gaussian
from molecule import molecule
from notebookImporter import importNotebook

#import integrals notebook for the hartree method
integrals = importNotebook("Hartree_Integrals")
scf = importNotebook("Hartree_SCF")

#define SCF convergence critera, and max number of iteration cycles
SCF_CONVERGENCE = pow(10, -100)
MAX_ITERATIONS = 100

#Step 1
#Specify Molecules, Nuclear Coordinates, and Charge of the nucli Number of Electrons,

#generate an h2 atom with a distance of 1.4 AU to compare with Szabo pg. 160

#R is in units of Bohr Radius 
R = 1.4
system = molecule()
system.addAtom(atom(vector(1,1,1), 1, 1))
system.addAtom(atom(vector(1,1,1), 1, 1))

#add a basis set
system.addBasis("DEF2-SVP")

system.display()
# Out:
# Molecule
# Basis Set: DEF2-SVP
# Total Number of Electrons: 2
# Atoms:
#      Atomic Number: 1, Electrons: 2, Coordinate: X: 1 Y: 1 Z: 1

# %%
#Step 2
#Calculate Integrals
#Overlap, KE, Nuclear Attraaction, and Electron Repulsion
S = integrals.overlap(system)
print("Overlap Matrix: ")
print(np.matrix(S))
print()

T = integrals.kineticEnergy(system)
print("Electron Kinetic Energy Matrix: ")
print(np.matrix(T))
print()

V = integrals.nuclearAttraction(system)
for index, atom in enumerate(V):
    print("Nucli " + str(index) + "-Electron Attraction Matrix: ")
    print(np.matrix(atom))
print()

electronRepulsion = integrals.electronElectronRepulsion(system)
print("Electron Repulsion Tensor: ")
print(np.array(electronRepulsion))
print()

#Form the electronic hamiltonian
H = np.matrix(T)

#add in all of the nuclear attractions matricies to the hamiltonian
for atom in V:
    H += np.matrix(atom)
        
print("Electronic Hamiltonian :")
print(H)
print()
# Out:
# Overlap Matrix:
# [[0.34548743 0.40251286]
#  [0.40251286 1.        ]]
#
# Electron Kinetic Energy Matrix:
# [[0.33485537 0.11822737]
#  [0.11822737 0.18292443]]
#
# Nucli 0-Electron Attraction Matrix:
# [[-0.47597637 -0.38180154]
#  [-0.38180154 -0.5572631 ]]
#
# Electron Repulsion Tensor:
# [[[[0.10708419 0.10246776]
#    [0.10246776 0.17525454]]
#
#   [[0.10246776 0.10362009]
#    [0.10362009 0.19040262]]]
#
#
#  [[[0.10246776 0.10362009]
#    [0.10362009 0.19040262]]
#
#   [[0.17525454 0.19040262]
#    [0.19040262 0.39404451]]]]
#
# Electronic Hamiltonian :
# [[-0.14112099 -0.26357418]
#  [-0.26357418 -0.37433867]]

# %%
#Prepare for the SCF procedure

#get size of the basis set 
size = len(S)

#compute the Transformation Matrix
X = scf.X(S, size)

#get guess Fock matrix, assume 2-electron term is equal to 0
F = H

# %%
# SCF Procedure 

#init list to store the energy from each iteration
#as well as a boolean to signify whether the loop has converged
E = []
converged = False

while( not converged ):
  
    #diagnolze the Fock matrix and convert it to MO basis 
    F = X.transpose() * F * X 
    
    #diagnolize the Fock Matrix to obtain the MOs and the their respective energies
    MOEnergy, MO = np.linalg.eigh(F)
    
    #Transform the MO basis MOs to an AO basis
    C = X * MO
    
    #compute the electron density, the two electron term, and then use G to compute the new Fock matrix
    P = scf.densityMatrix(C, system.N, size)
    G = scf.G(electronRepulsion, P, size)
    F = H + G
    
    #compute the new expectation energy
    #Expectation Energy is in units of Hartrees
    E.append(scf.expectationEnergy(H, F, P))
    
    #check if at least two SCF iterations have occured
    #if more than two have occured, then check if the difference betweeen this E, 
    #and the previous E is less then the covergence value, if yes, end the SCF loop
    #if energy has not converged, check whether the max number of iterations have occured so far
    sizeE = len(E)
    if(len(E) > 2):
        if(abs(E[sizeE-2] - E[sizeE-1]) < SCF_CONVERGENCE):
            converged = True
        elif(sizeE > MAX_ITERATIONS):
            print("SCF Failed to Converge")
            break
    
    #compute total energy of the system including nuclear-nuclear repulsion
    totalE = E[sizeE-1] + scf.nuclearRepulsion(system)
    
    #display information about current SCF iteration to the user
    print("SCF Iteration #" + str(sizeE) + ", Electronic Energy: " + str(E[sizeE-1]) + " Hartrees, Total Energy: " + str(totalE) + " Hartrees")
    
print("-"*50)
print()
print("Final SCF Energy: " + str(E[sizeE-1]))
print()
print(MOEnergy)
print(H)
# Out:
# SCF Iteration #1, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #2, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #3, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #4, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #5, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #6, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #7, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #8, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #9, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #10, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #11, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #12, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #13, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #14, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #15, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #16, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #17, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #18, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #19, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #20, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #21, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #22, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #23, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #24, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #25, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #26, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #27, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #28, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #29, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #30, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #31, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #32, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #33, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #34, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #35, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #36, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #37, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #38, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #39, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #40, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #41, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #42, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #43, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #44, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #45, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #46, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #47, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #48, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #49, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #50, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #51, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #52, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #53, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #54, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #55, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #56, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #57, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #58, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #59, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #60, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #61, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #62, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #63, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #64, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #65, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #66, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #67, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #68, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #69, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #70, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #71, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #72, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #73, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #74, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #75, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #76, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #77, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #78, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #79, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #80, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #81, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #82, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #83, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #84, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #85, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #86, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #87, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #88, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #89, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #90, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #91, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #92, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #93, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #94, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #95, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #96, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #97, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #98, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Iteration #99, Electronic Energy: 2.269122616984844 Hartrees, Total Energy: 2.269122616984844 Hartrees
# SCF Iteration #100, Electronic Energy: 2.269122616984846 Hartrees, Total Energy: 2.269122616984846 Hartrees
# SCF Failed to Converge
# --------------------------------------------------
#
# Final SCF Energy: 2.269122616984844
#
# [0.87784562 1.70885503]
# [[-0.14112099 -0.26357418]
#  [-0.26357418 -0.37433867]]
